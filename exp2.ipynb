# %% [markdown]
# <a href="https://colab.research.google.com/github/thecoderenroute/ml-notebooks/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("Housing.csv")
ds.head()
# Out:
#       price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0  13300000  7420         4  ...        2       yes        furnished
# 1  12250000  8960         4  ...        3        no        furnished
# 2  12250000  9960         3  ...        2       yes   semi-furnished
# 3  12215000  7500         4  ...        3       yes        furnished
# 4  11410000  7420         4  ...        2        no        furnished
#
# [5 rows x 13 columns]
